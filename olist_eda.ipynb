# %% [markdown]
# We have OLIST dataset, which is a dataset comprising of the sales from a Brazilian E-commerce store

# %% [markdown]
# The goal is to predict whether the customer will churn or not. To determine this, we need to first determine a threshold which can be used to define 'churn' because unlike Netflix and other subscription based services, we cannot determine customer churn simply by checking the subscription status

# %% [markdown]
# So, first we choose relevant files and try to find out what will be our baseline for churn

# %% [markdown]
# First, I'll start by creating a common data frame/set
#
# Setting aside some csv files that seem unimportant to the final verdict based on the features, the csv files we're going to use are :
#
# - [Olist Customers](data\olist_customers_dataset.csv) contains info on customers which is our main target
# - [Olist Order Items](data\olist_order_items_dataset.csv) contains price and fright value which might be important
# - [Olist Order Reviews](data\olist_order_reviews_dataset.csv) contains review score which might be relevant
# - [Olist Orders](data\olist_orders_dataset.csv) contains delivery info which might give important insights
# - [Olist Sellers](data\olist_sellers_dataset.csv) also might be interesting to look at

# %% [markdown]
# Now, we look at and combine these 5 into a single csv for exploratory analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
customers = pd.read_csv()
